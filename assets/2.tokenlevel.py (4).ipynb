# %% [markdown]
# ## Import the world

# %%
import pandas as pd
import numpy as np
from scipy import sparse
import os
import re
import sys
import json
from tqdm import tqdm
from pathlib import Path
qlvldir = "/home/aardvark/code/typetokenQLVL/"
sys.path.append(qlvldir)

from qlvl.conf import ConfigLoader
from qlvl import Vocab, TypeTokenMatrix
from qlvl import ItemFreqHandler, ColFreqHandler, TokenHandler
from qlvl import compute_association, compute_cosine, compute_distance, compute_simrank
from qlvl.basics.mxcalc import compute_token_weights, compute_token_vectors
from qlvl.models.typetoken import build_tc_weight_matrix

# %% [markdown]
# ### Paths

# %%
#coldir = "/home/semmetrix/collmtx-stefano/"
rootdir = "/home/artem/"
output_path = rootdir + "output/"
github_dir = "/home/artem/github"

# %% [markdown]
# ### Parameter settings
# Create an object conf to tune settings. During this initialization, conf has already read the default settings file (in `/home/aardvark/code/typetokenQLVL/qlvl/config.ini`) consisting default parameter settings.

# %%
conf = ConfigLoader()
settings = conf.settings
fnames = "{}/home/artem/artem_master/dry/j.tsv".format(rootdir)
# always print values to check before you use
settings['line-machine'] = '([^\t]+)\t([^\t]+)\t([^\t])[^\t]*'
settings['line-format'] = 'word,lemma,pos'
settings['token'] = 'lemma/pos/fid/lid'
print(settings['line-machine'])
print(settings['line-format'])
print(settings['type'], settings['colloc'], settings['token'])
settings['file-encoding'] = 'latin1'
settings['outfile-encoding'] = 'utf-8'
print(settings['file-encoding'])
print(settings['outfile-encoding'])
# output_path = settings['output-path']
settings['output-path'] = output_path
print(output_path)
settings['corpus-path'] = '/home/aardvark/corp/en/COCA'
print(settings['corpus-path'])
# Out:
# ([^	]+)	([^	]+)	([^	])[^	]*
# word,lemma,pos
# lemma/pos lemma/pos lemma/pos/fid/lid
# latin1
# utf-8
# /home/artem/output/
# /home/aardvark/corp/en/COCA

# %% [markdown]
# ## Token-level workflow
# The type of distributional semantic model used by QLVL on the token level is an adaptation of the approach by Schütze (1998). The model constructs a token vector by averaging over the type vectors of the context words around the target token. As a first step, we have to collect information about the context words that co-occur with specific occurrences (tokens) of a word. This token-by-context information will be stored in a boolean matrix which will then be the input for the averaging over context type vectors.

# %% [markdown]
# ### Load matrices

# %%
freq_fname = "/home/artem/output/COCA.cmplt.10_10.wcmx.freq.pac".format(rootdir)
freqMTX = TypeTokenMatrix.load(freq_fname)
node_vocab = Vocab(freqMTX.sum(axis=1))

# %%
print(node_vocab[:10])
len(node_vocab)
target = ['dry/j']
# Out:
# [(',/y', 538315457),('./y', 475155730),('the/a', 471685656) ... ('"/y', 156266380),('in/i', 150189851),('to/t', 136618730)]

# %% [markdown]
# ### Custom functions

# %% [markdown]
# We could select the context words by part-of-speech

# %%
def register_cws(tokens, params, init, tokenlist):
    colname1 = '_cws.' + '.'.join(params)
    colname2 = '_count.' + '.'.join(params)
    def count_cws(tokens, row):
        if row in tokens.row_items:
            return [c for c in tokens.col_items if not tokens[row, c] == 0]
        else:
            return []
    if colname1 in init.columns:
        return init
    else:
        df = pd.DataFrame(index = tokenlist) if len(init) == 0 else init
        df[colname1] = [';'.join(count_cws(tokens, r)) for r in df.index]
        df[colname2] = [len(count_cws(tokens, r)) for r in df.index]
        return df

# %%
def select_by_ppmi(freqMTX, target, context_words, node_vocab, full):
    subMTX = freqMTX.submatrix(row = target, col = context_words).drop(axis = 1, n_nonzero = 0)
    p = compute_association(subMTX, nfreq=node_vocab, cfreq=node_vocab, meas = 'pmi')
    pdf = p.dataframe.transpose()
    pdf.columns = ['pmi']
    pdf['raw_freq'] = [full[x] for x in pdf.index]
    pdf['raw_co'] = [subMTX[target[0], x] for x in pdf.index]
    pdf['cw'] = pdf.index
    pdf.to_csv("{}/{}.ppmi.tsv".format(output_path, lemma), sep = '\t', index=False)
    print(pdf.head())
    print("Stored with", len(p.col_items), "elements.")
    return p.multiply(p > 0).drop(axis = 1, n_nonzero = 0)

# %%
def apply_window(w, maxw, original):
    boolean = original.matrix.toarray() != 0
    if w < maxw:
        threshold = abs(original.matrix.toarray()) < (w+1)
        both = boolean & threshold
        boolean_tokens = sparse.csr_matrix(both.astype(np.int))
    else:
        boolean_tokens = sparse.csr_matrix(boolean.astype(np.int))
    return TypeTokenMatrix(boolean_tokens, original.row_items, original.col_items).drop(axis = 1, n_nonzero = 0)

# %%
def restrict_foc(pos, w, foc_cws, weighted):
    foc_cws2 = [x for x in foc_cws if x.rsplit('/', 1)[1] in ['n', 'j', 'v']] if pos == 'nav' else list(foc_cws)
    return list(foc_cws2) if w == 'no_ppmi' else [x for x in foc_cws2 if x in weighted]

# %%
def compute_tokweights(original, weights):
    subtwMTX = weights.submatrix(col = original.col_items)
    return compute_token_weights(original, subtwMTX)

# %%
def finalize_cloud(token_matrix, soc_matrix, soc_cols):
    ppmiMTX = socMTX.submatrix(row=tokweights.col_items, col=soc_cols)
    tokvecs = compute_token_vectors(tokweights, ppmiMTX)
    return compute_distance(tokvecs)

# %%
def collect_tokens(query, fnames, foc, sentence_boundary, selection, multicore = True):
    if sentence_boundary:
        settings['single-boundary-machine'] = '^</sentence>$'
    else:
        settings['single-boundary-machine'] = '^</artikel>$'
    tokhan = TokenHandler(query, settings=settings)
    tokens = tokhan.retrieve_tokens(col_vocab = foc, multicore = multicore)
    remaining = [x for x in selection if x in tokens.row_items]
    return tokens.submatrix(row = remaining).drop(axis = 1, n_nonzero = 0)
    fnames=None

# %% [markdown]
# ### Generate foc list

# %%
full_name = "/home/artem/output/COCA.foc.nodefreq"
full = Vocab.load(full_name)
full.encoding = 'utf-8'
full
# Out:
# [('be/v', 16767681),('and/c', 11709841),('of/i', 11167127) ... ('paglum/n', 11),('vovan/n', 11),('grafspee/n', 11)]

# %%
foc = full[full.match('item', '^[^/]+/[njrvidp]$')]
foc = foc[foc.freq > 10]
len(foc)
# Out:
# 165282

# %%
socs_fname = ("{}COCA.type.vocab".format(output_path))
ssocs = Vocab.load(socs_fname, encoding=settings["file-encoding"])
ssocs.encoding = "utf-8"
len(ssocs)
# Out:
# 2086194

# %% [markdown]
# #### Select files and tokens based on concordance

# %%
targets = ['dry/j']
lemma = targets[0].split('/')[0]
selection_file = '/home/artem/artem_master/dry/j.tsv'
with open(selection_file, 'r') as s:
    selection = [l.strip().split('\t')[0] for l in s.readlines()[1:]]
selection_file = [x.split('/')[2]+'.conll' for x in selection]
selection = ["/".join([x.split("/")[0], "j", x.split("/")[2], str(int(x.split("/")[3])+1)]) for x in selection]
selection
# Out:
# ['dry/j/wlp_fic_1998/2510335',
#  'dry/j/wlp_mag_2001/193487',
#  'dry/j/wlp_news_2000/2299529',
#  'dry/j/wlp_mag_2005/2395753',
#  'dry/j/wlp_spok_2005/5054386',
#  'dry/j/wlp_fic_1997/1707803',
#  'dry/j/wlp_mag_2002/759439',
#  'dry/j/wlp_fic_1991/4121017',
#  'dry/j/wlp_mag_1990/4035548',
#  'dry/j/wlp_news_1996/1870643',
#  'dry/j/wlp_fic_1995/2705707',
#  'dry/j/wlp_acad_1997/4698397',
#  'dry/j/wlp_mag_2004/2595711',
#  'dry/j/wlp_mag_2010/3102117',
#  'dry/j/wlp_acad_1994/4043938',
#  'dry/j/wlp_fic_2002/519949',
#  'dry/j/wlp_mag_1998/770974',
#  'dry/j/wlp_news_1991/3456153',
#  'dry/j/wlp_news_1992/3924109',
#  'dry/j/wlp_fic_2000/2020377',
#  'dry/j/wlp_mag_1999/1052827',
#  'dry/j/wlp_fic_2009/1877358',
#  'dry/j/wlp_news_1996/2532840',
#  'dry/j/wlp_fic_2007/1965267',
#  'dry/j/wlp_fic_2006/4154720',
#  'dry/j/wlp_spok_1993/4997011',
#  'dry/j/wlp_fic_2008/4043745',
#  'dry/j/wlp_mag_1990/287186',
#  'dry/j/wlp_spok_2008/3467789',
#  'dry/j/wlp_mag_2002/3441446',
#  'dry/j/wlp_mag_2008/3804165',
#  'dry/j/wlp_news_2011/3426529',
#  'dry/j/wlp_fic_1991/1609685',
#  'dry/j/wlp_fic_1995/3771202',
#  'dry/j/wlp_news_2004/2144163',
#  'dry/j/wlp_mag_2012/2152231',
#  'dry/j/wlp_news_1994/4030778',
#  'dry/j/wlp_acad_2000/3013033',
#  'dry/j/wlp_mag_1997/3960980',
#  'dry/j/wlp_acad_2001/599783',
#  'dry/j/wlp_fic_1992/585462',
#  'dry/j/wlp_news_2001/4788382',
#  'dry/j/wlp_fic_1995/1859094',
#  'dry/j/wlp_fic_2004/1172947',
#  'dry/j/wlp_spok_2000/1467251',
#  'dry/j/wlp_fic_2000/2561480',
#  'dry/j/wlp_acad_1990/4004045',
#  'dry/j/wlp_news_2002/4788589',
#  'dry/j/wlp_mag_1993/1492706',
#  'dry/j/wlp_fic_2007/3280141',
#  'dry/j/wlp_mag_2009/238136',
#  'dry/j/wlp_fic_2010/3430161',
#  'dry/j/wlp_acad_1996/4081031',
#  'dry/j/wlp_news_1996/652353',
#  'dry/j/wlp_acad_2006/1602575',
#  'dry/j/wlp_mag_2006/1210481',
#  'dry/j/wlp_news_2002/4290574',
#  'dry/j/wlp_mag_1990/1908948',
#  'dry/j/wlp_mag_2005/623626',
#  'dry/j/wlp_news_2007/4373653',
#  'dry/j/wlp_fic_1998/2286844',
#  'dry/j/wlp_acad_2007/3077944',
#  'dry/j/wlp_spok_2006/4735840',
#  'dry/j/wlp_news_2002/3116348',
#  'dry/j/wlp_mag_1997/1708247',
#  'dry/j/wlp_mag_1990/4595326',
#  'dry/j/wlp_mag_2007/2181526',
#  'dry/j/wlp_fic_1990/1108116',
#  'dry/j/wlp_mag_2010/3829754',
#  'dry/j/wlp_mag_2009/3067362',
#  'dry/j/wlp_mag_2005/846654',
#  'dry/j/wlp_mag_1997/2860444',
#  'dry/j/wlp_fic_2005/2511301',
#  'dry/j/wlp_acad_1999/19209',
#  'dry/j/wlp_news_2007/780826',
#  'dry/j/wlp_news_2002/4759890',
#  'dry/j/wlp_fic_1993/4417920',
#  'dry/j/wlp_acad_1994/4420047',
#  'dry/j/wlp_spok_2007/3847300',
#  'dry/j/wlp_fic_2010/2384132',
#  'dry/j/wlp_mag_2003/1570241',
#  'dry/j/wlp_mag_1997/3956504',
#  'dry/j/wlp_news_1993/700863',
#  'dry/j/wlp_mag_2005/1787939',
#  'dry/j/wlp_fic_2000/3943564',
#  'dry/j/wlp_mag_2012/53809',
#  'dry/j/wlp_mag_2005/1660458',
#  'dry/j/wlp_spok_2011/755597',
#  'dry/j/wlp_mag_2002/921959',
#  'dry/j/wlp_mag_1999/3607073',
#  'dry/j/wlp_fic_1994/2503776',
#  'dry/j/wlp_mag_2012/877539',
#  'dry/j/wlp_mag_1997/361394',
#  'dry/j/wlp_mag_1998/2799342',
#  'dry/j/wlp_fic_2006/2803232',
#  'dry/j/wlp_news_1995/2329713',
#  'dry/j/wlp_mag_2012/1572395',
#  'dry/j/wlp_fic_2012/1901033',
#  'dry/j/wlp_acad_1992/435812',
#  'dry/j/wlp_news_2012/984539',
#  'dry/j/wlp_news_2005/3200123',
#  'dry/j/wlp_mag_2004/979220',
#  'dry/j/wlp_mag_1993/706906',
#  'dry/j/wlp_fic_2002/1874746',
#  'dry/j/wlp_spok_1993/2498559',
#  'dry/j/wlp_mag_2006/1719934',
#  'dry/j/wlp_news_2002/737376',
#  'dry/j/wlp_fic_1992/2825780',
#  'dry/j/wlp_spok_2001/3757314',
#  'dry/j/wlp_spok_1990/2813169',
#  'dry/j/wlp_fic_2004/708',
#  'dry/j/wlp_fic_2001/471847',
#  'dry/j/wlp_news_1998/963220',
#  'dry/j/wlp_mag_2001/837375',
#  'dry/j/wlp_mag_1990/307288',
#  'dry/j/wlp_mag_1997/4000641',
#  'dry/j/wlp_mag_2002/1316168',
#  'dry/j/wlp_mag_2009/1558927',
#  'dry/j/wlp_mag_1996/4116776',
#  'dry/j/wlp_acad_1999/17104',
#  'dry/j/wlp_mag_1992/497848',
#  'dry/j/wlp_spok_1999/3935487',
#  'dry/j/wlp_acad_1999/13265',
#  'dry/j/wlp_spok_2010/166886',
#  'dry/j/wlp_mag_2012/1192151',
#  'dry/j/wlp_news_2010/2046977',
#  'dry/j/wlp_mag_2000/1425004',
#  'dry/j/wlp_acad_1999/10574',
#  'dry/j/wlp_news_1999/1892370',
#  'dry/j/wlp_spok_2000/1821802',
#  'dry/j/wlp_fic_1996/2264904',
#  'dry/j/wlp_mag_2002/1686652',
#  'dry/j/wlp_fic_1991/3786993',
#  'dry/j/wlp_mag_2001/3250536',
#  'dry/j/wlp_fic_2003/623470',
#  'dry/j/wlp_mag_2009/772663',
#  'dry/j/wlp_fic_1993/970726',
#  'dry/j/wlp_fic_2004/3461324',
#  'dry/j/wlp_news_2005/2924343',
#  'dry/j/wlp_fic_2000/1008187',
#  'dry/j/wlp_mag_2008/1248158',
#  'dry/j/wlp_news_2007/521410',
#  'dry/j/wlp_fic_2009/317253',
#  'dry/j/wlp_mag_2011/1699529',
#  'dry/j/wlp_fic_1999/2605412',
#  'dry/j/wlp_mag_1998/1693452',
#  'dry/j/wlp_mag_1991/3930933',
#  'dry/j/wlp_mag_2005/1324132',
#  'dry/j/wlp_news_1999/1951799',
#  'dry/j/wlp_mag_2008/1274470',
#  'dry/j/wlp_mag_2002/470994',
#  'dry/j/wlp_fic_1993/2186567',
#  'dry/j/wlp_fic_1992/1722225',
#  'dry/j/wlp_mag_2012/1546902',
#  'dry/j/wlp_mag_1993/1183772',
#  'dry/j/wlp_acad_1994/1216428',
#  'dry/j/wlp_acad_1991/1160870',
#  'dry/j/wlp_fic_2009/670312',
#  'dry/j/wlp_acad_2007/2575304',
#  'dry/j/wlp_news_1994/2956779',
#  'dry/j/wlp_acad_1999/4076803',
#  'dry/j/wlp_mag_1992/4767911',
#  'dry/j/wlp_mag_2006/3785353',
#  'dry/j/wlp_mag_1998/68315',
#  'dry/j/wlp_mag_2007/2729461',
#  'dry/j/wlp_acad_2011/187579',
#  'dry/j/wlp_acad_1998/4323542',
#  'dry/j/wlp_mag_1996/3746256',
#  'dry/j/wlp_mag_1996/2953415',
#  'dry/j/wlp_mag_1999/3543760',
#  'dry/j/wlp_fic_1999/3655437',
#  'dry/j/wlp_fic_1999/2365881',
#  'dry/j/wlp_acad_2008/4060766',
#  'dry/j/wlp_acad_2011/1384515',
#  'dry/j/wlp_mag_1994/4562970',
#  'dry/j/wlp_mag_2008/1534547',
#  'dry/j/wlp_fic_1998/515039',
#  'dry/j/wlp_spok_2004/4979075',
#  'dry/j/wlp_fic_1996/1862965',
#  'dry/j/wlp_fic_2012/1716928',
#  'dry/j/wlp_news_2005/3642561',
#  'dry/j/wlp_news_1992/4122154',
#  'dry/j/wlp_mag_2004/3688425',
#  'dry/j/wlp_spok_2004/2143403',
#  'dry/j/wlp_acad_2008/4065516',
#  'dry/j/wlp_news_2006/3720424',
#  'dry/j/wlp_news_1996/2598143',
#  'dry/j/wlp_fic_1996/4475328',
#  'dry/j/wlp_mag_1991/4670702',
#  'dry/j/wlp_news_2008/158776',
#  'dry/j/wlp_mag_2012/2486140',
#  'dry/j/wlp_mag_2001/421676',
#  'dry/j/wlp_news_2011/3855496',
#  'dry/j/wlp_spok_2002/975436',
#  'dry/j/wlp_fic_2011/1147019',
#  'dry/j/wlp_acad_1998/4093589',
#  'dry/j/wlp_fic_1993/1957010',
#  'dry/j/wlp_fic_1991/3355856',
#  'dry/j/wlp_fic_2003/2757174',
#  'dry/j/wlp_mag_1998/1605728',
#  'dry/j/wlp_acad_2012/1625591',
#  'dry/j/wlp_mag_1994/4002266',
#  'dry/j/wlp_fic_2009/945897',
#  'dry/j/wlp_mag_2003/107404',
#  'dry/j/wlp_fic_2009/3365752',
#  'dry/j/wlp_news_1992/2525463',
#  'dry/j/wlp_fic_1990/722885',
#  'dry/j/wlp_fic_2003/2941697',
#  'dry/j/wlp_news_2009/2754877',
#  'dry/j/wlp_fic_2004/2737016',
#  'dry/j/wlp_news_1994/4687090',
#  'dry/j/wlp_acad_2007/3331048',
#  'dry/j/wlp_mag_1996/2953408',
#  'dry/j/wlp_fic_1991/4831679',
#  'dry/j/wlp_mag_2010/2049520',
#  'dry/j/wlp_mag_2000/1525192',
#  'dry/j/wlp_news_2008/947637',
#  'dry/j/wlp_news_2000/734312',
#  'dry/j/wlp_fic_2007/1145390',
#  'dry/j/wlp_mag_1993/444929',
#  'dry/j/wlp_mag_2009/2907400',
#  'dry/j/wlp_mag_2004/3269364',
#  'dry/j/wlp_fic_2006/3165455',
#  'dry/j/wlp_acad_1998/3760049',
#  'dry/j/wlp_spok_2007/4153783',
#  'dry/j/wlp_news_1994/4776481',
#  'dry/j/wlp_mag_1996/1752692',
#  'dry/j/wlp_spok_1990/669895',
#  'dry/j/wlp_mag_1997/361625',
#  'dry/j/wlp_mag_1995/1373513',
#  'dry/j/wlp_fic_2008/4171428',
#  'dry/j/wlp_news_2008/3961830',
#  'dry/j/wlp_fic_1990/2512079',
#  'dry/j/wlp_news_2012/1050739',
#  'dry/j/wlp_news_2006/2116334',
#  'dry/j/wlp_spok_2010/1095472',
#  'dry/j/wlp_spok_1990/2040617',
#  'dry/j/wlp_acad_2000/3529570',
#  'dry/j/wlp_fic_1999/2576336',
#  'dry/j/wlp_acad_1996/931894',
#  'dry/j/wlp_fic_1999/2738509',
#  'dry/j/wlp_fic_2004/625615',
#  'dry/j/wlp_fic_2006/95049',
#  'dry/j/wlp_mag_2004/4063179',
#  'dry/j/wlp_fic_2002/2046064',
#  'dry/j/wlp_acad_1998/4303768',
#  'dry/j/wlp_news_1990/3505160',
#  'dry/j/wlp_acad_1993/4497275',
#  'dry/j/wlp_acad_1994/2164450',
#  'dry/j/wlp_fic_1994/2808419',
#  'dry/j/wlp_acad_2011/4746343',
#  'dry/j/wlp_news_2004/216402',
#  'dry/j/wlp_fic_2000/3663364',
#  'dry/j/wlp_acad_2005/2571672',
#  'dry/j/wlp_fic_2010/2803927',
#  'dry/j/wlp_mag_2011/710446',
#  'dry/j/wlp_fic_2006/4051520',
#  'dry/j/wlp_fic_1997/2233546',
#  'dry/j/wlp_mag_1992/993454',
#  'dry/j/wlp_fic_2009/3714023',
#  'dry/j/wlp_acad_2011/2252576',
#  'dry/j/wlp_mag_2003/583783',
#  'dry/j/wlp_news_1993/2345111',
#  'dry/j/wlp_news_2006/4494538',
#  'dry/j/wlp_mag_2007/3828172',
#  'dry/j/wlp_mag_2007/3105229',
#  'dry/j/wlp_mag_1994/4572184',
#  'dry/j/wlp_mag_2005/421420',
#  'dry/j/wlp_spok_2008/3649180',
#  'dry/j/wlp_acad_1994/4047382',
#  'dry/j/wlp_mag_2000/409179',
#  'dry/j/wlp_mag_2004/1115731',
#  'dry/j/wlp_fic_2010/710648',
#  'dry/j/wlp_mag_1991/2300180',
#  'dry/j/wlp_acad_2005/2396970',
#  'dry/j/wlp_fic_1993/2273090',
#  'dry/j/wlp_mag_2008/2329619',
#  'dry/j/wlp_news_2010/2234235',
#  'dry/j/wlp_mag_2001/762952',
#  'dry/j/wlp_news_2005/3373664',
#  'dry/j/wlp_fic_2003/1015961',
#  'dry/j/wlp_mag_2002/3415059',
#  'dry/j/wlp_mag_2010/583152',
#  'dry/j/wlp_mag_2012/568101',
#  'dry/j/wlp_news_2008/820955',
#  'dry/j/wlp_news_2000/2847104',
#  'dry/j/wlp_news_2009/2311850',
#  'dry/j/wlp_acad_1998/4305027',
#  'dry/j/wlp_fic_1998/185699',
#  'dry/j/wlp_mag_2011/4652755',
#  'dry/j/wlp_news_1997/2788215',
#  'dry/j/wlp_mag_2001/4145851',
#  'dry/j/wlp_spok_2010/3940591',
#  'dry/j/wlp_mag_1996/4029532',
#  'dry/j/wlp_news_2006/1373629',
#  'dry/j/wlp_spok_1994/2142642',
#  'dry/j/wlp_mag_1996/487563',
#  'dry/j/wlp_mag_1996/3342635',
#  'dry/j/wlp_mag_2003/3472454',
#  'dry/j/wlp_news_2005/2912302']

# %%
with open('/home/artem/artem_master/dry/j.tsv', 'r') as m:
    numbers = [l.strip().split('\t')[0] for l in m.readlines()[1:]]
tokid=[x.split('/')[3] for x in numbers]
print(tokid[:10])
print(len(tokid))
k = np.unique(np.array(tokid)) 
print(len(k))
# Out:
# ['2510334', '193486', '2299528', '2395752', '5054385', '1707802', '759438', '4121016', '4035547', '1870642']
# 300
# 300

# %% [markdown]
# #### Tokens within sentence boundaries

# %%
bound = 'bound'
query = full[target]
files_list = '/home/artem/artem_master/dry/j.tsv'

# %%
tokens_bound = collect_tokens(query, fnames, foc, (bound == 'bound'), selection)
# Out:
# Scanning tokens of queries in corpus...
# Starting subprocess 35931
# Starting subprocess 35933
# Starting subprocess 35932
# Starting subprocess 35934
# Starting subprocess 35930
# Starting subprocess 35929
# Starting subprocess 35928
# Starting subprocess 35935
# Starting subprocess 35936
# Starting subprocess 35938
# Starting subprocess 35939
# Starting subprocess 35937
# Starting subprocess 35941
# Starting subprocess 35944
# Starting subprocess 35942
# Starting subprocess 35943
# Starting subprocess 35945
# Starting subprocess 35946
# Starting subprocess 35940
# Starting subprocess 35947
# Starting subprocess 35949
# Starting subprocess 35950
# Starting subprocess 35948
# HBox(children=(IntProgress(value=0, description='  proc(35939)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35944)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35930)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35928)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35938)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35946)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35933)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35945)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35949)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35936)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35931)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35950)', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35947)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35943)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35937)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35942)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35948)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35941)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35934)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35932)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35935)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35940)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(35929)', max=16), HTML(value='')))
# ************************************
# function    = retrieve_tokens
#   time      = 1.658e+03 sec
# ************************************

# %%
tokens_bound
# Out:
# [300, 1758]                  a/r  abandon/v  abandoned/j  abby/n  abound/v  about/i  about/r  ...
# dry/j/wlp_fic_1998/2510335   NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# dry/j/wlp_mag_2001/193487    NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# dry/j/wlp_news_2000/2299529  NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# dry/j/wlp_mag_2005/2395753   NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# dry/j/wlp_spok_2005/5054386  NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# dry/j/wlp_fic_1997/1707803   NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# dry/j/wlp_mag_2002/759439    NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# ...                          ...  ...        ...          ...     ...       ...      ...      ...

# %% [markdown]
# #### Tokens regardless of sentence boundaries

# %%
bound = 'nobound'

# %%
tokens_nobound = collect_tokens(query, fnames, foc, (bound == 'nobound'), selection)
# Out:
# Scanning tokens of queries in corpus...
# Starting subprocess 38365
# Starting subprocess 38364
# Starting subprocess 38366
# Starting subprocess 38368
# Starting subprocess 38367
# Starting subprocess 38363
# Starting subprocess 38369
# Starting subprocess 38372
# Starting subprocess 38370
# Starting subprocess 38373
# Starting subprocess 38378
# Starting subprocess 38377
# Starting subprocess 38379
# Starting subprocess 38374
# Starting subprocess 38380
# Starting subprocess 38376
# Starting subprocess 38375
# Starting subprocess 38371
# Starting subprocess 38382
# Starting subprocess 38381
# Starting subprocess 38383
# Starting subprocess 38384
# Starting subprocess 38385
# HBox(children=(IntProgress(value=0, description='  proc(38377)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38363)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38368)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38375)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38380)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38383)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38379)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38371)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38374)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38369)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38373)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38384)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38364)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38367)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38381)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38365)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38378)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38376)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38372)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38370)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38366)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38382)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(38385)', max=15), HTML(value='')))
# ************************************
# function    = retrieve_tokens
#   time      = 1.664e+03 sec
# ************************************

# %%
tokens_nobound
# Out:
# [300, 1758]                  a/r  abandon/v  abandoned/j  abby/n  abound/v  about/i  about/r  ...
# dry/j/wlp_fic_1998/2510335   NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# dry/j/wlp_mag_2001/193487    NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# dry/j/wlp_news_2000/2299529  NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# dry/j/wlp_mag_2005/2395753   NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# dry/j/wlp_spok_2005/5054386  NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# dry/j/wlp_fic_1997/1707803   NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# dry/j/wlp_mag_2002/759439    NaN  NaN        NaN          NaN     NaN       NaN      NaN      ...
# ...                          ...  ...        ...          ...     ...       ...      ...      ...

# %% [markdown]
# ### Vary along parameters

# %% [markdown]
# ##### PPMI weighting

# %% [markdown]
# I use the 10-10 window ppmi frequencies, but could also use 4-4 (it's just... yet another parameter!)

# %%
ppmi = select_by_ppmi(freqMTX, target, tokens_nobound.col_items, node_vocab, full)
ppmi # for weighting and selection of foc_words
# Out:
# HBox(children=(IntProgress(value=0, max=1758), HTML(value='')))
# ************************************
# function    = compute_association
#   time      = 0.1154 sec
# ************************************
#
#                   pmi  raw_freq  raw_co           cw
# a/r          0.256693    147218     194          a/r
# abandon/v   -0.047088     16412      16    abandon/v
# abandoned/j  0.979789      3680      10  abandoned/j
# abby/n       0.394993      2644       4       abby/n
# abound/v     0.995243      2533       7     abound/v
# Stored with 1758 elements.
# [1, 1156]  a/r       abandoned/j  abby/n      abound/v    about/r     above/r     abs/n      ...
# dry/j      0.256693  0.97978854   0.39499322  0.99524295  0.37369668  0.38923192  1.2994517  ...

# %%
tokens_registration = pd.DataFrame()
models_registration = pd.DataFrame()

# %%
boundaries = ['bound'] # could also be ['bound', 'nobound']
focbows = [10, 5]
focpos = ['nav', 'all']
focweight = ['ppmi_weight', 'ppmi_sel', 'no_ppmi'] # we'll use the ppmi values of the cw10 for weighting any time we weight (**ppmi**)
socbows = [4, 10]
socpos = ['nav', 'all']
min_feats = [1] # could have more values
soclengths = [5000, 10000, 'foc']

# %%
foc_combinations = [(pos, w, thres) for pos in focpos for w in focweight for thres in min_feats]
soc_combinations = [(pos, win, length) for pos in socpos for win in socbows for length in soclengths]
print(foc_combinations)
print(soc_combinations)
# Out:
# [('nav', 'ppmi_weight', 1), ('nav', 'ppmi_sel', 1), ('nav', 'no_ppmi', 1), ('all', 'ppmi_weight', 1), ('all', 'ppmi_sel', 1), ('all', 'no_ppmi', 1)]
# [('nav', 4, 5000), ('nav', 4, 10000), ('nav', 4, 'foc'), ('nav', 10, 5000), ('nav', 10, 10000), ('nav', 10, 'foc'), ('all', 4, 5000), ('all', 4, 10000), ('all', 4, 'foc'), ('all', 10, 5000), ('all', 10, 10000), ('all', 10, 'foc')]

# %%
socMTX = freqMTX.submatrix(row=tokens_nobound.col_items, col=foc.get_item_list())
ppmi = compute_association(socMTX, nfreq=node_vocab, cfreq=node_vocab, meas='ppmi')
# Out:
# HBox(children=(IntProgress(value=0, max=41878453), HTML(value='')))
# ************************************
# function    = compute_association
#   time      = 337.1 sec
# ************************************

# %%
settings['left-span']
# Out:
# 10

# %%
len(tokens_registration)
# Out:
# 0

# %%
for bound in boundaries:
    tokens = tokens_bound if bound == 'bound' else tokens_nobound
    for ctxt in focbows:
        # apply context window - tokens => new_tokens; foc_cws are the remaining cws
        after_window = apply_window(ctxt, settings['left-span'], tokens)
        foc_1 = after_window.col_items
        for f in foc_combinations:
            fpos, w, t = f
            foc_final = restrict_foc(fpos, w, foc_1, ppmi.col_items)
            tokens_foc_final = after_window.submatrix(col = foc_final).drop(axis = 0, n_nonzero = (t-1))
            tokweights = compute_tokweights(tokens_foc_final, ppmi) if w == 'ppmi_weight' else tokens_foc_final
            # Register first order values
            tokens_registration = register_cws(tokweights, [lemma, 'foc' + str(ctxt), fpos, w, bound], tokens_registration,selection)
            for soc in soc_combinations:
                spos, win, length = soc
                socs = ssocs if spos == 'nav' else foc
                soc_cols = list(tokweights.col_items) if type(length) == str else socs[:length].get_item_list()
                socMTX = ppmi# not perfectly safe
                tokdists = finalize_cloud(tokweights, socMTX, soc_cols)
                modelname = '.'.join([lemma,
                                      "foc" + str(ctxt), fpos, w, bound, 'min'+str(t),
                                      "soc" + str(win), spos, str(length)])
                parameters = {'_model' : modelname, 'type' : lemma,
                              'foc_window' : '{}_{}'.format(ctxt, ctxt), 'foc_part_of_speech' : fpos,
                              'foc_weighting' : w, 'foc_minimum_features': t,
                              'foc_sent_bound' : bound, 'foc_length' : len(tokens_foc_final.col_items),
                              'soc_part_of_speech' : spos, 'soc_window' : '{}_{}'.format(win, win),
                              'soc_length' : length, 'soc_length_num' : len(soc_cols), 
                              'tokens' : str(int(len(tokdists.row_items)))}
                models_registration = models_registration.append(parameters, ignore_index = True)
                tokdists.save("{}/{}/{}.ttmx.dist".format(output_path, lemma, modelname))
# Out:
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.09513 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1094 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02238 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.06072 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1095 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01844 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05473 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1088 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01905 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05557 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1064 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01846 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05536 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1095 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01895 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05521 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1093 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01862 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05506 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1077 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01857 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0557 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1077 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.019 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05543 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1092 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01853 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05566 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.109 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01898 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05574 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1076 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01851 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0553 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1076 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01861 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05523 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1091 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02089 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05487 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.109 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02123 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05583 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1085 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02096 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05577 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1089 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02095 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0565 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1101 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0214 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05643 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.11 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02137 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05627 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1099 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02104 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05634 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1098 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02097 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05646 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1099 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02098 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05638 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1099 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02104 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05663 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1097 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02108 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05659 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1092 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02133 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05884 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.12 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01091 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0589 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1195 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01081 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05443 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1202 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01083 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05471 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.121 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01081 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05785 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1189 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01111 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05835 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1189 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01107 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0574 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1196 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01153 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05587 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1203 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01151 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05837 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1192 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01112 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05874 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1195 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01108 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05577 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1198 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01109 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05554 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1213 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01118 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05446 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1166 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01249 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05457 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1161 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01215 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05437 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1184 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01219 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05443 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1189 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01218 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05452 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.12 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01239 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05452 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.119 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01233 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05484 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1192 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01237 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05475 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1199 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01267 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05493 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.119 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01232 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05495 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1199 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01245 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05514 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1197 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01236 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05506 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1201 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01253 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc10.all.foc.ttmx.dist.pac

# %%
len(models_registration.drop_duplicates())
# Out:
# 144

# %%
models_registration = models_registration.drop_duplicates()
models_registration.to_csv("{}/{}/{}.models.tsv".format(github_dir, lemma, lemma), sep="\t", index = False)

# %%
len(tokens_registration)
# Out:
# 300

# %%
tokens_registration.to_csv("{}/{}/{}.cws.tsv".format(github_dir, lemma, lemma), sep='\t', index_label = '_id')

# %% [markdown]
# ### Test in one

# %%
boundaries = ['nobound', 'bound']
focbows = [5]
focpos = ['nav']
focweight = ['ppmi_weight'] # we'll use the ppmi values of the cw10 for weighting any time we weight (**ppmi**)
socbows = [4]
socpos = ['all', 'nav']
min_feats = [1, 2]
soclengths = ['foc']

# %%
foc_combinations = [(pos, w, thres) for pos in focpos for w in focweight for thres in min_feats]
soc_combinations = [(pos, win, length) for pos in socpos for win in socbows for length in soclengths]
print(foc_combinations)
print(soc_combinations)
# Out:
# [('nav', 'ppmi_weight', 1), ('nav', 'ppmi_weight', 2)]
# [('all', 4, 'foc'), ('nav', 4, 'foc')]

# %%
settings['left-span']
# Out:
# 10

# %%
socMTX = freqMTX.submatrix(row=tokens_nobound.col_items, col=foc.get_item_list())
ppmi = compute_association(socMTX, nfreq=node_vocab, cfreq=node_vocab, meas='ppmi')
# Out:
# HBox(children=(IntProgress(value=0, max=41878453), HTML(value='')))
# ************************************
# function    = compute_association
#   time      = 318.6 sec
# ************************************

# %%
lemma
# Out:
# 'dry'

# %%
lemma = ('dry')
tokens_registration = pd.DataFrame()
models_registration = pd.DataFrame()

boundaries = ['bound', 'nobound'] # could also be ['bound', 'nobound']
focbows = [10, 5]
focpos = ['nav', 'all']
focweight = ['ppmi_weight', 'ppmi_sel', 'no_ppmi'] # we'll use the ppmi values of the cw10 for weighting any time we weight (**ppmi**)
socbows = [4, 10]
socpos = ['nav', 'all']
min_feats = [1] # could have more values
soclengths = ["5000", "10000", 'foc']

foc_combinations = [(pos, w, thres) for pos in focpos for w in focweight for thres in min_feats]
soc_combinations = [(pos, win, length) for pos in socpos for win in socbows for length in soclengths]

for bound in boundaries:
    tokens = collect_tokens(query, files_list, foc, ('bound','nobound'), selection)
    ppmi = select_by_ppmi(freqMTX, target, tokens.col_items, node_vocab, full)
    socMTX = freqMTX.submatrix(row=tokens.col_items, col=foc.get_item_list())

    for ctxt in focbows:
        # apply context window - tokens => new_tokens; foc_cws are the remaining cws
        after_window = apply_window(ctxt, settings['left-span'], tokens)
        foc_1 = after_window.col_items
        for f in foc_combinations:
            fpos, w, t = f
            foc_final = restrict_foc(fpos, w, foc_1, ppmi.col_items)
            tokens_foc_final = after_window.submatrix(col = foc_final).drop(axis = 0, n_nonzero = (t-1))
            tokweights = compute_tokweights(tokens_foc_final, ppmi) if w == 'ppmi_weight' else tokens_foc_final
            # Register first order values
            tokens_registration = register_cws(tokweights, [lemma, 'foc' + str(ctxt), fpos, w, bound], tokens_registration,selection)
            
            for soc in soc_combinations:
                spos, win, length = soc
                socs = ssocs if spos == 'nav' else foc
                soc_cols = socs[:int(length)].get_item_list() if length.isdigit() else list(tokweights.col_items)
                socMTX = ppmi # not perfectly safe
                tokdists = finalize_cloud(tokweights, socMTX, soc_cols)
                modelname = '.'.join([lemma,
                                      "foc" + str(ctxt), fpos, w, bound, 'min'+str(t),
                                      "soc" + str(win), spos, str(length)])
                parameters = {'_model' : modelname, 'type' : lemma,
                              'foc_window' : '{}_{}'.format(ctxt, ctxt), 'foc_part_of_speech' : fpos,
                              'foc_weighting' : w, 'foc_minimum_features': t,
                              'foc_sent_bound' : bound, 'foc_length' : len(tokens_foc_final.col_items),
                              'soc_part_of_speech' : spos, 'soc_window' : '{}_{}'.format(win, win),
                              'soc_length' : length, 'soc_length_num' : len(soc_cols), 
                              'tokens' : str(int(len(tokdists.row_items)))}
                models_registration = models_registration.append(parameters, ignore_index = True)
                tokdists.save("{}/{}/{}.ttmx.dist".format(output_path, lemma, modelname))
models_registration = models_registration.drop_duplicates()
models_registration.to_csv("{}/{}/{}.models.tsv".format(github_dir, lemma, lemma), sep="\t", index = False)
# Out:
# Scanning tokens of queries in corpus...
# Starting subprocess 56790
# Starting subprocess 56791
# Starting subprocess 56792
# Starting subprocess 56793
# Starting subprocess 56794
# Starting subprocess 56795
# Starting subprocess 56802
# Starting subprocess 56789
# Starting subprocess 56801
# Starting subprocess 56800
# Starting subprocess 56804
# Starting subprocess 56803
# Starting subprocess 56805
# Starting subprocess 56796
# Starting subprocess 56798
# Starting subprocess 56807
# Starting subprocess 56810
# Starting subprocess 56806
# Starting subprocess 56811
# Starting subprocess 56808
# Starting subprocess 56799
# Starting subprocess 56797
# Starting subprocess 56809
# HBox(children=(IntProgress(value=0, description='  proc(56792)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56791)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56800)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56797)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56807)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56811)', max=15), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56802)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56794)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56793)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56810)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56789)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56805)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56806)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56795)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56801)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56804)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56796)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56790)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56799)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56809)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56803)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56798)', max=16), HTML(value='')))
# HBox(children=(IntProgress(value=0, description='  proc(56808)', max=16), HTML(value='')))
# ************************************
# function    = retrieve_tokens
#   time      = 1.661e+03 sec
# ************************************
# HBox(children=(IntProgress(value=0, max=1758), HTML(value='')))
# ************************************
# function    = compute_association
#   time      = 0.0867 sec
# ************************************
#
#                   pmi  raw_freq  raw_co           cw
# a/r          0.256693    147218     194          a/r
# abandon/v   -0.047088     16412      16    abandon/v
# abandoned/j  0.979789      3680      10  abandoned/j
# abby/n       0.394993      2644       4       abby/n
# abound/v     0.995243      2533       7     abound/v
# Stored with 1758 elements.
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0577 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1508 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0159 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05674 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1505 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.016 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05719 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1509 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0159 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05717 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1511 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01601 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_weight.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05693 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1501 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01577 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05691 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1501 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01589 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05654 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1507 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01573 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05673 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1509 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01618 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.ppmi_sel.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05762 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1471 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02231 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05737 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1471 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0223 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05718 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1494 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02235 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05748 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1499 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02237 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.nav.no_ppmi.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05637 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.148 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01678 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05658 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.148 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01681 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05654 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1503 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01717 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05615 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1497 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01688 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_weight.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05658 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1484 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01721 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05591 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.148 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01684 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05603 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1498 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01698 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05601 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1499 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01679 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.ppmi_sel.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05683 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1467 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02296 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05685 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1465 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02298 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0572 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1472 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02304 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05723 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.148 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.02336 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc10.all.no_ppmi.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05587 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1188 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.009692 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05549 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1191 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.009781 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05563 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1192 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.009741 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05579 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1188 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.009727 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_weight.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05542 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1187 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.009656 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05583 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1185 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.009677 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05574 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1191 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.009684 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05528 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1191 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.009722 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0574 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.148 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01291 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05747 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1479 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01298 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05745 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1505 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01289 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05746 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1508 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01299 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05677 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1205 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01099 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05644 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1204 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01094 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0564 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.121 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01089 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05676 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.121 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01094 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05653 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1202 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01086 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05683 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1203 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01089 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05674 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1205 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01121 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05664 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1211 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01085 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.bound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05659 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1464 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01482 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05617 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1467 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01479 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05645 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.148 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.bound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01477 sec
# ...
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1183 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.nobound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.009602 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.ppmi_sel.nobound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05752 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.nobound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1481 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.nobound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01333 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.nobound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0578 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.nobound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1476 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.nobound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0133 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.nobound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05778 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.nobound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1482 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.nobound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01298 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.nobound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05783 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.nobound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1488 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.nobound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01323 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.nav.no_ppmi.nobound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05688 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.nobound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1206 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.nobound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01086 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.nobound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05648 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.nobound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1207 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.nobound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01112 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.nobound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05683 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.nobound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1206 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.nobound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01076 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.nobound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.0566 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.nobound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1206 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.nobound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01075 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_weight.nobound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05688 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.nobound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.121 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.nobound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01071 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.nobound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05658 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.nobound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1206 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.nobound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01069 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.nobound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05648 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.nobound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1205 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.nobound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01074 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.nobound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05669 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.nobound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1206 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.nobound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01073 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.ppmi_sel.nobound.min1.soc10.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05671 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.nobound.min1.soc4.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1468 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.nobound.min1.soc4.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01465 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.nobound.min1.soc4.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05637 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.nobound.min1.soc10.nav.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1468 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.nobound.min1.soc10.nav.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01467 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.nobound.min1.soc10.nav.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05628 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.nobound.min1.soc4.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.1469 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.nobound.min1.soc4.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01467 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.nobound.min1.soc4.all.foc.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.05675 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.nobound.min1.soc10.all.5000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.147 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.nobound.min1.soc10.all.10000.ttmx.dist.pac
#   Operation: 'token-feature weight matrix' X 'socc matrix'...
#
# ************************************
# function    = compute_distance
#   time      = 0.01504 sec
# ************************************
#
#
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.nobound.min1.soc10.all.foc.ttmx.dist.pac

# %%
"home/artem/output/COCA.cmplt.10_10.wcmx.freq.pac".encode("utf-8")
# Out:
# b'home/artem/output/COCA.cmplt.10_10.wcmx.freq.pac'

# %%
# Out:
# Saving matrix...
# Stored in file:
#   /home/artem/output//dry/dry.foc5.all.no_ppmi.nobound.min1.soc10.all.foc.ttmx.dist.pac
